# %%
import numpy as np
import tensorflow as tf
import math
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, GRU, Flatten

import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Book14.csv', delimiter=',')
data = data.astype('float32')

data = data.to_numpy()
X= data[:,0:3]
Y= data[:,3:6]
Z=data[:,6:9]
data

Y1= Y.reshape((Y.shape[0], Y.shape[1], 1))
print(data.shape)
x3 = X.reshape((X.shape[0], X.shape[1], 1))
print(x3.shape)
# Out:
# (2100, 9)
# (2100, 3, 1)

# %%
import tensorflow.keras
tensorflow.keras.backend.backend()
# Out:
# 'tensorflow'

# %%
model = Sequential()

model.add(LSTM(3, activation='relu', input_shape=(x3.shape[1:]),return_sequences=True))
model.add(LSTM(units=128, activation='relu', return_sequences=True))

model.add(LSTM(512, activation='relu',return_sequences=True))

model.add(LSTM(16, activation='relu',return_sequences=False))
model.add(Dense(3, activation='linear'))
di=list()
Z1=data[:,6:9]
def my_loss(y_true,y_pred):
    Z1=data[:,6:9]
    z1=Z1.reshape((Z1.shape[0], Z1.shape[1], 1))
    sd=tf.square(y_true-y_pred)/z1
    return sd

model.compile(loss= my_loss, optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 3, 3)              60
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 3, 128)            67584
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 3, 512)            1312768
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 16)                33856
# _________________________________________________________________
# dense (Dense)                (None, 3)                 51
# ...
# Total params: 1,414,319
# Trainable params: 1,414,319
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x3,Y, epochs=500, batch_size=1)
# Out:
# Epoch 1/500
# WARNING:tensorflow:AutoGraph could not transform <function my_loss at 0x000002208FD3A4C0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function my_loss at 0x000002208FD3A4C0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2100/2100 [==============================] - 27s 13ms/step - loss: 51.2288
# Epoch 2/500
# ...

# %%
dif=list()
y_pred= model.predict(x3)
value = y_pred
dif.append(value)

y1=np.asarray(value)
y1.shape
y2=y1.reshape(2100,-1)

y2.shape
np.savetxt('trainLSTM.csv', y2, delimiter=',')

# %%
data=pd.read_csv('Book13.csv', delimiter=',')
data = data.astype('float32')
data = data.to_numpy()
X= data[:,0:3]
X1=X.reshape((X.shape[0], X.shape[1], 1))
Y= data[:,3:6]
di=list()

y_pred= model.predict(X1)
value = y_pred
di.append(value)

y1=np.asarray(value)
y1.shape
np.savetxt('testLSTM.csv', y1, delimiter=',')

# %%
dat=pd.read_csv('s1i-5.csv')
dat.shape
dat = dat.astype('float32')
dat = dat.to_numpy()
X1=dat[:,:3]
X1=X1.reshape((X1.shape[0], X1.shape[1], 1))
Y3=dat[:,3:6]
dif=list()
y_pre=model.predict(X1)
valu= y_pre
dif.append(valu)
y2=np.asarray(dif)
y5= y2.reshape(150,-1)
x1=dat[:,2:3]
y3=dat[:,3:4]
y4= y5[:,:1]
y5
# Out:
# array([[ 1.41447854e+00,  2.42335243e+01,  3.91099548e+00],
#        [ 1.85625434e+00,  2.42092190e+01,  2.95863676e+00],
#        [ 2.51057220e+00,  2.42011642e+01,  1.95735502e+00],
#        [ 3.52736998e+00,  2.41912689e+01,  1.05458403e+00],
#        [ 4.63482952e+00,  2.42327499e+01,  5.08122444e-02],
#        [ 5.76596260e+00,  2.43603592e+01, -1.02389073e+00],
#        [ 7.04968452e+00,  2.44868488e+01, -1.89078426e+00],
#        [ 8.27507782e+00,  2.46135044e+01, -2.54041457e+00],
#        [ 9.54654121e+00,  2.47100792e+01, -3.05029225e+00],
#        [ 1.08007355e+01,  2.47805405e+01, -3.38014555e+00],
#        [ 1.20185671e+01,  2.48256931e+01, -3.53782701e+00],
#        [ 1.31979361e+01,  2.48435936e+01, -3.51868153e+00],
#        [ 1.43304720e+01,  2.48273830e+01, -3.31556153e+00],
#        [ 1.53922796e+01,  2.47403469e+01, -2.97615385e+00],
#        [ 1.63500748e+01,  2.45684738e+01, -2.52083778e+00],
#        [ 1.71866646e+01,  2.43176556e+01, -1.99156570e+00],
# ...

# %%
plt.plot(x1,y3)
plt.plot(x1,y4)

# %%
import multiprocessing as mp
print("numer of processors:", mp.cpu_count())
# Out:
# numer of processors: 16

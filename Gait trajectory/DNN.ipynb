# %%
import numpy as np
import math
import pandas as pd
import sklearn
from keras.models import Sequential
from keras.layers import Dense, Dropout,Flatten
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Book14.csv', delimiter=',')
data = data.astype('float32')
data = data.to_numpy()
X= data[:,0:3]
Y= data[:,3:6]
Z=data[:,6:9]
data
# Out:
# array([[0.25      , 0.5       , 0.        , ..., 4.1897063 , 5.772317  ,
#         3.826948  ],
#        [0.25      , 0.5       , 0.00671141, ..., 4.5570464 , 5.715867  ,
#         3.8074374 ],
#        [0.25      , 0.5       , 0.01342282, ..., 4.92427   , 5.6702023 ,
#         3.788133  ],
#        ...,
#        [0.5       , 0.875     , 0.98657715, ..., 3.4779472 , 5.7960405 ,
#         1.738264  ],
#        [0.5       , 0.875     , 0.9932886 , ..., 3.4846706 , 5.7656775 ,
#         1.7652811 ],
#        [0.5       , 0.875     , 1.        , ..., 3.5075116 , 5.7342067 ,
#         1.8096167 ]], dtype=float32)

# %%
import keras
keras.backend.backend()
# Out:
# 'tensorflow'

# %%
model = Sequential()
model.add(Dense(3, input_dim=3, activation='relu'))

model.add(Dense(128, activation='relu'))

model.add(Dense(512, activation='relu'))

model.add(Dense(16, activation='relu'))

model.add(Dense(3, activation='linear'))

# %%
di=list()
Z=data[:,6:9]
def my_loss(y_true,y_pred):
    Z=data[:,6:9]
    sd=tf.math.abs(y_true-y_pred)/Z
    return sd

model.compile(loss= my_loss, optimizer='adam')

# %%
model.fit(X, Y, epochs=500, batch_size=1)
# Out:
# Epoch 1/500
# 2100/2100 [==============================] - 4s 2ms/step - loss: 2.1824
# Epoch 2/500
# 2100/2100 [==============================] - 4s 2ms/step - loss: 2.0705
# Epoch 3/500
# 2100/2100 [==============================] - 4s 2ms/step - loss: 1.9611
# Epoch 4/500
# 2100/2100 [==============================] - 4s 2ms/step - loss: 1.6859
# Epoch 5/500
# 2100/2100 [==============================] - 4s 2ms/step - loss: 1.4140
# Epoch 6/500
# 2100/2100 [==============================] - 4s 2ms/step - loss: 1.2922
# Epoch 7/500
# 2100/2100 [==============================] - 4s 2ms/step - loss: 1.1871
# Epoch 8/500
# 2100/2100 [==============================] - 4s 2ms/step - loss: 1.0603
# Epoch 9/500
# 2100/2100 [==============================] - 4s 2ms/step - loss: 0.9026
# Epoch 10/500
# 2100/2100 [==============================] - 4s 2ms/step - loss: 0.7600
# Epoch 11/500
# 2100/2100 [==============================] - 3s 2ms/step - loss: 0.6539
# Epoch 12/500
# ...

# %%
#model.save("my_model1")

# %%
#loaded_2 = keras.models.load_model("my_model", custom_objects={"my_loss": my_loss})

# %%
#loaded_2.fit(X,Y, epochs=800, batch_size=1)

# %%
data=pd.read_csv('Book13.csv', delimiter=',')
data = data.astype('float32')
data = data.to_numpy()
X1= data[:,0:3]
Y= data[:,3:6]
di=list()
y_pred= model.predict(X1)
value = y_pred
di.append(value)

y1=np.asarray(value)
y1.shape
y2=y1.reshape(1950,-1)

y2.shape
np.savetxt('test.csv', y2, delimiter=',')

# %%
dif=list()
y_pred= model.predict(X)
value = y_pred
dif.append(value)

y1=np.asarray(value)
y1.shape
y2=y1.reshape(2100,-1)

y2.shape
np.savetxt('train.csv', y2, delimiter=',')

# %%
dat=pd.read_csv('s1i-5.csv')
dat.shape
dat = dat.astype('float32')
dat = dat.to_numpy()

# %%
X1=dat[:,:3]
Y3=dat[:,3:6]
dif=list()
y_pre=model.predict(X1)
valu= y_pre
dif.append(valu)
y2=np.asarray(dif)
y5= y2.reshape(150,-1)
x1=X1[:,2:3]
y3=dat[:,3:4]
y4= y5[:,:1]
y5
np.savetxt('data.csv', y5, delimiter=',')

# %%
plt.plot(x1,y3)
plt.plot(x1,y4)

# %%
di=list()
def my_loss(Y3,y5):
  z=dat[:,6:9]
  sd=tf.square(Y3-y5)/z
  di.append(sd)
  return di
g=my_loss(Y3,y5)
g1 = np.asarray(g)
g1= g1.reshape(150,-1)
g1.shape
# Out:
# (150, 3)

# %%
g1
# Out:
# array([[2.32167765e-02, 2.82324962e-02, 2.28707299e-01],
#        [2.81815305e-02, 2.69272756e-02, 1.42637312e-01],
#        [1.83930621e-02, 2.66180672e-02, 7.21639097e-02],
#        [1.14186490e-02, 2.75374930e-02, 2.56513171e-02],
#        [1.30070904e-02, 3.34721766e-02, 2.54381653e-02],
#        [2.38435324e-02, 4.43547182e-02, 2.04687659e-02],
#        [3.42456102e-02, 5.46039492e-02, 1.74511150e-02],
#        [1.12707233e-02, 3.36362794e-02, 3.00249029e-02],
#        [2.80971552e-04, 1.59300882e-02, 2.12503932e-02],
#        [4.23561898e-04, 1.95613597e-02, 5.94317988e-02],
#        [7.93186657e-04, 1.82964504e-02, 5.72957136e-02],
#        [2.08036785e-04, 1.31750721e-02, 3.15469764e-02],
#        [1.03064252e-04, 1.79465935e-02, 4.15354855e-02],
#        [4.78865299e-03, 1.48696601e-02, 2.66286470e-02],
#        [1.36325210e-02, 6.58098143e-03, 1.31590432e-02],
#        [3.58280241e-02, 4.94546432e-04, 6.48073945e-03],
# ...

# %%
data=pd.read_csv('Book.csv', delimiter=',')
data = data.astype('float32')
data = data.to_numpy()
X= data[:,0:3]
Y= data[:,3:6]
Z=data[:,6:9]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-68-b5dcdee45956> in <module>()
# ----> 1 data=pd.read_csv('Book.csv', delimiter=',')
#       2 data = data.astype('float32')
#       3 data = data.to_numpy()
#       4 X= data[:,0:3]
#       5 Y= data[:,3:6]
#
# ...
